# %%
import numpy as np
import pandas as pd

from src.service.market import PriceService

market_price = PriceService(
    db_path = '../database/alternative_data.duckdb'
)

# %%
market_price.get_series(
    symbols = 'KOSPI',
    index_set = 'release_date'
)['close'].plot()
# Out:
# <Axes: xlabel='release_date'>
