# %%
import numpy as np
import pandas as pd
import financedatabase as fd

# %%
indices = fd.Indices()

# %%
ind_info = indices.select()

# %%
ind_info['exchange'].unique()
# Out:
# <ArrowStringArray>
# ['SHH', 'ZRH',   nan, 'GER', 'STU', 'PAR', 'TLV', 'SHZ', 'AMS', 'FGI', 'FSI',
#  'VIE', 'BRU', 'EBS', 'MCX', 'PHS', 'BSE', 'ATH', 'CSE', 'MEX', 'MCE', 'ENX',
#  'SAO', 'TAI', 'JKT', 'IST', 'LIS', 'TWO', 'HKG', 'TSI', 'NYB', 'PRA', 'SES',
#  'MIL', 'NZE', 'BUE', 'NIM', 'CCS', 'KSC', 'NSI', 'CAI', 'OSL', 'SGO', 'DJI',
#  'ASE', 'NYS', 'SNP', 'ASX', 'SET', 'WCB', 'RIS', 'BUD', 'STO', 'DOH', 'ISE',
#  'JNB', 'KLS', 'KOE', 'OSA', 'SAU', 'TAL', 'LIT', 'VAN', 'OPI']
# Length: 64, dtype: str

# %%
ind_info[ind_info['exchange'] == 'SNP']
# Out:
#                                      name currency  \
# symbol
# ^AEDW     Alerian Midstream Energy Divide      USD
# ^AEDWN    Alerian Midstream Energy Divide      USD
# ^AEDWT    Alerian Midstream Energy Divide      USD
# ^AEIPR    American Energy Independence Pr      USD
# ^AEITR    American Energy Independence To      USD
# ...                                   ...      ...
# ^WTJSE    WisdomTree Japan SmallCap Equit      USD
# ^WTJSEH   WisdomTree Japan Hedged SmallCa      USD
# ^WTUKEB   WisdomTree UK Equity Income Ind      GBP
# ^YLDX300                              NaN      USD
# ^YLDX400                              NaN      USD
#
#                                                     summary category_group  \
# symbol
# ^AEDW     The Alerian Midstream Energy Dividend Index is...         Energy
# ^AEDWN    The Alerian Midstream Energy Dividend Index is...         Energy
# ^AEDWT    The Alerian Midstream Energy Dividend Index is...         Energy
# ...

# %%
equities = fd.Equities()

# %%
equities.show_options()
# Out:
# {'currency': <ArrowStringArray>
#  ['ARS', 'AUD', 'BRL', 'CAD', 'CHF', 'CLP', 'CNY', 'COP', 'CZK', 'DKK', 'EUR',
#   'GBP', 'HKD', 'HUF', 'IDR', 'ILA', 'ILS', 'INR', 'ISK', 'JPY', 'KES', 'KRW',
#   'LKR', 'MXN', 'MYR', 'NOK', 'NZD', 'PEN', 'PHP', 'PLN', 'QAR', 'RUB', 'SAR',
#   'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD', 'ZAC', 'ZAR']
#  Length: 41, dtype: str,
#  'sector': <ArrowStringArray>
#  ['Communication Services', 'Consumer Discretionary',       'Consumer Staples',
#                   'Energy',             'Financials',            'Health Care',
#              'Industrials', 'Information Technology',              'Materials',
#              'Real Estate',              'Utilities']
#  Length: 11, dtype: str,
#  'industry_group': <ArrowStringArray>
#  [                      'Automobiles & Components',
#                                            'Banks',
#                                    'Capital Goods',
#               'Commercial & Professional Services',
# ...

# %%
equity_sample = equities.select()

# %%
len(equity_sample)
# Out:
# 151074

# %%
equity_sample[equity_sample['market'] == 'New York Stock Exchange']
# Out:
#                                                       name  \
# symbol
# A                               Agilent Technologies, Inc.
# AA                                       Alcoa Corporation
# AAMI            Acadian Asset Management Inc. Common Stock
# AAP                               Advance Auto Parts, Inc.
# AAQC-UN                       Accelerate Acquisition Corp.
# ...                                                    ...
# ZTS                                               TIS Inc.
# ZVIA                        Zevia PBC Class A Common Stock
# ZVV                                                    NaN
# ZWS      Zurn Elkay Water Solutions Corporation Common ...
# ZYME                                        Zymeworks Inc.
#
#                                                    summary currency  \
# symbol
# A        Agilent Technologies, Inc. provides applicatio...      USD
# AA       Alcoa Corporation, together with its subsidiar...      USD
# ...
